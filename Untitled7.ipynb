# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinitrajputt/algo-trader/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install buildozer
# Out:
# Requirement already satisfied: buildozer in /usr/local/lib/python3.10/dist-packages (1.5.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.10/dist-packages (from buildozer) (4.8.0)
# Requirement already satisfied: virtualenv in /usr/local/lib/python3.10/dist-packages (from buildozer) (20.24.3)
# Requirement already satisfied: sh in /usr/local/lib/python3.10/dist-packages (from buildozer) (2.0.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect->buildozer) (0.7.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.10/dist-packages (from virtualenv->buildozer) (0.3.7)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.10/dist-packages (from virtualenv->buildozer) (3.12.2)
# Requirement already satisfied: platformdirs<4,>=3.9.1 in /usr/local/lib/python3.10/dist-packages (from virtualenv->buildozer) (3.10.0)

# %%
# !pip install cython==0.29.21
# Out:
# Collecting cython==0.29.21
#   Downloading Cython-0.29.21-py2.py3-none-any.whl (974 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.2/974.2 kB 9.2 MB/s eta 0:00:00
# Installing collected packages: cython
#   Attempting uninstall: cython
#     Found existing installation: Cython 0.29.36
#     Uninstalling Cython-0.29.36:
#       Successfully uninstalled Cython-0.29.36
# Successfully installed cython-0.29.21

# %%
# !sudo apt-get install -y \
    python3-pip \
    build-essential \
    git \
    python3 \
    python3-dev \
    ffmpeg \
    libsdl2-dev \
    libsdl2-image-dev \
    libsdl2-mixer-dev \
    libsdl2-ttf-dev \
    libportmidi-dev \
    libswscale-dev \
    libavformat-dev \
    libavcodec-dev \
    zlib1g-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# git is already the newest version (1:2.34.1-1ubuntu1.10).
# python3 is already the newest version (3.10.6-1~22.04).
# python3 set to manually installed.
# python3-dev is already the newest version (3.10.6-1~22.04).
# python3-dev set to manually installed.
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# zlib1g-dev set to manually installed.
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# libavcodec-dev is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# libavcodec-dev set to manually installed.
# libavformat-dev is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# libavformat-dev set to manually installed.
# libswscale-dev is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# libswscale-dev set to manually installed.
# The following additional packages will be installed:
#   gir1.2-ibus-1.0 libblkid-dev libdbus-1-dev libdecor-0-dev libdrm-dev
#   libegl-dev libegl1-mesa-dev libffi-dev libfluidsynth3 libgbm-dev libgl-dev
#   libgles-dev libgles1 libglib2.0-dev libglib2.0-dev-bin libglu1-mesa
#   libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev libibus-1.0-5
#   libibus-1.0-dev libice-dev libinstpatch-1.0-2 libmodplug1 libmount-dev
#   libopengl-dev libopusfile0 libpciaccess-dev libportmidi0 libpulse-dev
#   libpulse-mainloop-glib0 libsdl2-image-2.0-0 libsdl2-mixer-2.0-0
#   libsdl2-ttf-2.0-0 libselinux1-dev libsepol-dev libsm-dev libsndio-dev
#   libudev-dev libwayland-bin libwayland-dev libxcursor-dev libxfixes-dev
#   libxi-dev libxinerama-dev libxkbcommon-dev libxrandr-dev libxt-dev libxv-dev
#   libxxf86vm-dev python3-setuptools python3-wheel timgm6mb-soundfont
# Suggested packages:
#   libgirepository1.0-dev libglib2.0-doc libgdk-pixbuf2.0-bin
#   | libgdk-pixbuf2.0-dev libxml2-utils libice-doc libsm-doc libwayland-doc
#   libxt-doc python-setuptools-doc fluid-soundfont-gm
# The following NEW packages will be installed:
#   gir1.2-ibus-1.0 libblkid-dev libdbus-1-dev libdecor-0-dev libdrm-dev
#   libegl-dev libegl1-mesa-dev libffi-dev libfluidsynth3 libgbm-dev libgl-dev
#   libgles-dev libgles1 libglib2.0-dev libglib2.0-dev-bin libglu1-mesa
#   libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev libibus-1.0-5
#   libibus-1.0-dev libice-dev libinstpatch-1.0-2 libmodplug1 libmount-dev
#   libopengl-dev libopusfile0 libpciaccess-dev libportmidi-dev libportmidi0
#   libpulse-dev libpulse-mainloop-glib0 libsdl2-dev libsdl2-image-2.0-0
#   libsdl2-image-dev libsdl2-mixer-2.0-0 libsdl2-mixer-dev libsdl2-ttf-2.0-0
#   libsdl2-ttf-dev libselinux1-dev libsepol-dev libsm-dev libsndio-dev
#   libudev-dev libwayland-bin libwayland-dev libxcursor-dev libxfixes-dev
#   libxi-dev libxinerama-dev libxkbcommon-dev libxrandr-dev libxt-dev libxv-dev
#   libxxf86vm-dev python3-pip python3-setuptools python3-wheel
#   timgm6mb-soundfont
# 0 upgraded, 60 newly installed, 0 to remove and 16 not upgraded.
# Need to get 15.3 MB of archives.
# After this operation, 58.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libibus-1.0-5 amd64 1.5.26-4 [183 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 gir1.2-ibus-1.0 amd64 1.5.26-4 [88.3 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdbus-1-dev amd64 1.12.20-2ubuntu4.1 [188 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-bin amd64 1.20.0-1ubuntu0.1 [20.4 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libffi-dev amd64 3.4.2-4 [63.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-dev amd64 1.20.0-1ubuntu0.1 [69.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdecor-0-dev amd64 0.1.0-3build1 [5,544 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpciaccess-dev amd64 0.16-3 [21.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-dev amd64 2.4.113-2~ubuntu0.22.04.1 [292 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libegl1-mesa-dev amd64 23.0.4-0ubuntu1~22.04.1 [10.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libinstpatch-1.0-2 amd64 1.1.6-1 [240 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/universe amd64 timgm6mb-soundfont all 1.3-5 [5,427 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfluidsynth3 amd64 2.2.5-1 [246 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgbm-dev amd64 23.0.4-0ubuntu1~22.04.1 [9,542 B]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-dev-bin amd64 2.72.4-0ubuntu2.2 [117 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libblkid-dev amd64 2.37.2-4ubuntu3 [185 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsepol-dev amd64 3.3-1build1 [378 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libselinux1-dev amd64 3.3-1build2 [158 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmount-dev amd64 2.37.2-4ubuntu3 [14.5 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-dev amd64 2.72.4-0ubuntu2.2 [1,739 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa-dev amd64 9.0.2-1 [231 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libibus-1.0-dev amd64 1.5.26-4 [185 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libice-dev amd64 2:1.0.10-1build2 [51.4 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmodplug1 amd64 1:0.8.9.0-3 [153 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopusfile0 amd64 0.9+20170913-1.1build1 [43.2 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libportmidi0 amd64 1:217-6 [17.8 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libportmidi-dev amd64 1:217-6 [52.2 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpulse-mainloop-glib0 amd64 1:15.99.1+dfsg1-1ubuntu2.1 [12.4 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpulse-dev amd64 1:15.99.1+dfsg1-1ubuntu2.1 [75.6 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsndio-dev amd64 1.8.1-1.1 [17.8 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev-dev amd64 249.11-0ubuntu3.9 [20.7 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfixes-dev amd64 1:6.0.0-1 [12.2 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcursor-dev amd64 1:1.2.0-2build4 [28.2 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxi-dev amd64 2:1.8-1build1 [193 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxinerama-dev amd64 2:1.1.4-3 [8,104 B]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-dev amd64 1.4.0-1 [54.9 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxrandr-dev amd64 2:1.5.2-1build1 [26.7 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsm-dev amd64 2:1.2.3-1build2 [18.1 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxt-dev amd64 1:1.2.1-1 [396 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxv-dev amd64 2:1.0.11-1build2 [33.4 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86vm-dev amd64 1:1.1.4-1build3 [13.9 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsdl2-dev amd64 2.0.20+dfsg-2ubuntu1.22.04.1 [1,767 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsdl2-image-2.0-0 amd64 2.0.5+dfsg1-3build1 [70.4 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsdl2-image-dev amd64 2.0.5+dfsg1-3build1 [76.9 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsdl2-mixer-2.0-0 amd64 2.0.4+dfsg1-4build1 [65.9 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsdl2-mixer-dev amd64 2.0.4+dfsg1-4build1 [83.3 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsdl2-ttf-2.0-0 amd64 2.0.18+dfsg-2 [30.9 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsdl2-ttf-dev amd64 2.0.18+dfsg-2 [35.9 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-setuptools all 59.6.0-1.2ubuntu0.22.04.1 [339 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-wheel all 0.37.1-2ubuntu0.22.04.1 [32.0 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip all 22.0.2+dfsg-1ubuntu0.3 [1,305 kB]
# Fetched 15.3 MB in 5s (3,121 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 60.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libibus-1.0-5:amd64.
# (Reading database ... 120831 files and directories currently installed.)
# Preparing to unpack .../00-libibus-1.0-5_1.5.26-4_amd64.deb ...
# Unpacking libibus-1.0-5:amd64 (1.5.26-4) ...
# Selecting previously unselected package gir1.2-ibus-1.0:amd64.
# Preparing to unpack .../01-gir1.2-ibus-1.0_1.5.26-4_amd64.deb ...
# Unpacking gir1.2-ibus-1.0:amd64 (1.5.26-4) ...
# Selecting previously unselected package libdbus-1-dev:amd64.
# Preparing to unpack .../02-libdbus-1-dev_1.12.20-2ubuntu4.1_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.12.20-2ubuntu4.1) ...
# Selecting previously unselected package libwayland-bin.
# Preparing to unpack .../03-libwayland-bin_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-bin (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../04-libffi-dev_3.4.2-4_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.4.2-4) ...
# Selecting previously unselected package libwayland-dev:amd64.
# Preparing to unpack .../05-libwayland-dev_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-dev:amd64 (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package libdecor-0-dev:amd64.
# Preparing to unpack .../06-libdecor-0-dev_0.1.0-3build1_amd64.deb ...
# Unpacking libdecor-0-dev:amd64 (0.1.0-3build1) ...
# Selecting previously unselected package libpciaccess-dev:amd64.
# Preparing to unpack .../07-libpciaccess-dev_0.16-3_amd64.deb ...
# Unpacking libpciaccess-dev:amd64 (0.16-3) ...
# Selecting previously unselected package libdrm-dev:amd64.
# Preparing to unpack .../08-libdrm-dev_2.4.113-2~ubuntu0.22.04.1_amd64.deb ...
# Unpacking libdrm-dev:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../09-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../10-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../11-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../12-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../13-libgles1_1.4.0-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../14-libgles-dev_1.4.0-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../15-libopengl-dev_1.4.0-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../16-libglvnd-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl1-mesa-dev:amd64.
# Preparing to unpack .../17-libegl1-mesa-dev_23.0.4-0ubuntu1~22.04.1_amd64.deb ...
# Unpacking libegl1-mesa-dev:amd64 (23.0.4-0ubuntu1~22.04.1) ...
# Selecting previously unselected package libinstpatch-1.0-2:amd64.
# Preparing to unpack .../18-libinstpatch-1.0-2_1.1.6-1_amd64.deb ...
# Unpacking libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Selecting previously unselected package timgm6mb-soundfont.
# Preparing to unpack .../19-timgm6mb-soundfont_1.3-5_all.deb ...
# Unpacking timgm6mb-soundfont (1.3-5) ...
# Selecting previously unselected package libfluidsynth3:amd64.
# Preparing to unpack .../20-libfluidsynth3_2.2.5-1_amd64.deb ...
# Unpacking libfluidsynth3:amd64 (2.2.5-1) ...
# Selecting previously unselected package libgbm-dev:amd64.
# Preparing to unpack .../21-libgbm-dev_23.0.4-0ubuntu1~22.04.1_amd64.deb ...
# Unpacking libgbm-dev:amd64 (23.0.4-0ubuntu1~22.04.1) ...
# Selecting previously unselected package libglib2.0-dev-bin.
# Preparing to unpack .../22-libglib2.0-dev-bin_2.72.4-0ubuntu2.2_amd64.deb ...
# Unpacking libglib2.0-dev-bin (2.72.4-0ubuntu2.2) ...
# Selecting previously unselected package libblkid-dev:amd64.
# Preparing to unpack .../23-libblkid-dev_2.37.2-4ubuntu3_amd64.deb ...
# Unpacking libblkid-dev:amd64 (2.37.2-4ubuntu3) ...
# Selecting previously unselected package libsepol-dev:amd64.
# Preparing to unpack .../24-libsepol-dev_3.3-1build1_amd64.deb ...
# Unpacking libsepol-dev:amd64 (3.3-1build1) ...
# Selecting previously unselected package libselinux1-dev:amd64.
# Preparing to unpack .../25-libselinux1-dev_3.3-1build2_amd64.deb ...
# Unpacking libselinux1-dev:amd64 (3.3-1build2) ...
# Selecting previously unselected package libmount-dev:amd64.
# Preparing to unpack .../26-libmount-dev_2.37.2-4ubuntu3_amd64.deb ...
# Unpacking libmount-dev:amd64 (2.37.2-4ubuntu3) ...
# Selecting previously unselected package libglib2.0-dev:amd64.
# Preparing to unpack .../27-libglib2.0-dev_2.72.4-0ubuntu2.2_amd64.deb ...
# Unpacking libglib2.0-dev:amd64 (2.72.4-0ubuntu2.2) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../28-libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Selecting previously unselected package libglu1-mesa-dev:amd64.
# Preparing to unpack .../29-libglu1-mesa-dev_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Selecting previously unselected package libibus-1.0-dev:amd64.
# Preparing to unpack .../30-libibus-1.0-dev_1.5.26-4_amd64.deb ...
# Unpacking libibus-1.0-dev:amd64 (1.5.26-4) ...
# Selecting previously unselected package libice-dev:amd64.
# Preparing to unpack .../31-libice-dev_2%3a1.0.10-1build2_amd64.deb ...
# Unpacking libice-dev:amd64 (2:1.0.10-1build2) ...
# Selecting previously unselected package libmodplug1:amd64.
# Preparing to unpack .../32-libmodplug1_1%3a0.8.9.0-3_amd64.deb ...
# Unpacking libmodplug1:amd64 (1:0.8.9.0-3) ...
# Selecting previously unselected package libopusfile0.
# Preparing to unpack .../33-libopusfile0_0.9+20170913-1.1build1_amd64.deb ...
# Unpacking libopusfile0 (0.9+20170913-1.1build1) ...
# Selecting previously unselected package libportmidi0:amd64.
# Preparing to unpack .../34-libportmidi0_1%3a217-6_amd64.deb ...
# Unpacking libportmidi0:amd64 (1:217-6) ...
# Selecting previously unselected package libportmidi-dev.
# Preparing to unpack .../35-libportmidi-dev_1%3a217-6_amd64.deb ...
# Unpacking libportmidi-dev (1:217-6) ...
# Selecting previously unselected package libpulse-mainloop-glib0:amd64.
# Preparing to unpack .../36-libpulse-mainloop-glib0_1%3a15.99.1+dfsg1-1ubuntu2.1_amd64.deb ...
# Unpacking libpulse-mainloop-glib0:amd64 (1:15.99.1+dfsg1-1ubuntu2.1) ...
# Selecting previously unselected package libpulse-dev:amd64.
# Preparing to unpack .../37-libpulse-dev_1%3a15.99.1+dfsg1-1ubuntu2.1_amd64.deb ...
# Unpacking libpulse-dev:amd64 (1:15.99.1+dfsg1-1ubuntu2.1) ...
# Selecting previously unselected package libsndio-dev:amd64.
# Preparing to unpack .../38-libsndio-dev_1.8.1-1.1_amd64.deb ...
# Unpacking libsndio-dev:amd64 (1.8.1-1.1) ...
# Selecting previously unselected package libudev-dev:amd64.
# Preparing to unpack .../39-libudev-dev_249.11-0ubuntu3.9_amd64.deb ...
# Unpacking libudev-dev:amd64 (249.11-0ubuntu3.9) ...
# Selecting previously unselected package libxfixes-dev:amd64.
# Preparing to unpack .../40-libxfixes-dev_1%3a6.0.0-1_amd64.deb ...
# Unpacking libxfixes-dev:amd64 (1:6.0.0-1) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../41-libxcursor-dev_1%3a1.2.0-2build4_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.2.0-2build4) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../42-libxi-dev_2%3a1.8-1build1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.8-1build1) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../43-libxinerama-dev_2%3a1.1.4-3_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.4-3) ...
# Selecting previously unselected package libxkbcommon-dev:amd64.
# Preparing to unpack .../44-libxkbcommon-dev_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../45-libxrandr-dev_2%3a1.5.2-1build1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.2-1build1) ...
# Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../46-libsm-dev_2%3a1.2.3-1build2_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.3-1build2) ...
# Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../47-libxt-dev_1%3a1.2.1-1_amd64.deb ...
# Unpacking libxt-dev:amd64 (1:1.2.1-1) ...
# Selecting previously unselected package libxv-dev:amd64.
# Preparing to unpack .../48-libxv-dev_2%3a1.0.11-1build2_amd64.deb ...
# Unpacking libxv-dev:amd64 (2:1.0.11-1build2) ...
# Selecting previously unselected package libxxf86vm-dev:amd64.
# Preparing to unpack .../49-libxxf86vm-dev_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libxxf86vm-dev:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libsdl2-dev:amd64.
# Preparing to unpack .../50-libsdl2-dev_2.0.20+dfsg-2ubuntu1.22.04.1_amd64.deb ...
# Unpacking libsdl2-dev:amd64 (2.0.20+dfsg-2ubuntu1.22.04.1) ...
# Selecting previously unselected package libsdl2-image-2.0-0:amd64.
# Preparing to unpack .../51-libsdl2-image-2.0-0_2.0.5+dfsg1-3build1_amd64.deb ...
# Unpacking libsdl2-image-2.0-0:amd64 (2.0.5+dfsg1-3build1) ...
# Selecting previously unselected package libsdl2-image-dev:amd64.
# Preparing to unpack .../52-libsdl2-image-dev_2.0.5+dfsg1-3build1_amd64.deb ...
# Unpacking libsdl2-image-dev:amd64 (2.0.5+dfsg1-3build1) ...
# Selecting previously unselected package libsdl2-mixer-2.0-0:amd64.
# Preparing to unpack .../53-libsdl2-mixer-2.0-0_2.0.4+dfsg1-4build1_amd64.deb ...
# Unpacking libsdl2-mixer-2.0-0:amd64 (2.0.4+dfsg1-4build1) ...
# Selecting previously unselected package libsdl2-mixer-dev:amd64.
# Preparing to unpack .../54-libsdl2-mixer-dev_2.0.4+dfsg1-4build1_amd64.deb ...
# Unpacking libsdl2-mixer-dev:amd64 (2.0.4+dfsg1-4build1) ...
# Selecting previously unselected package libsdl2-ttf-2.0-0:amd64.
# Preparing to unpack .../55-libsdl2-ttf-2.0-0_2.0.18+dfsg-2_amd64.deb ...
# Unpacking libsdl2-ttf-2.0-0:amd64 (2.0.18+dfsg-2) ...
# Selecting previously unselected package libsdl2-ttf-dev:amd64.
# Preparing to unpack .../56-libsdl2-ttf-dev_2.0.18+dfsg-2_amd64.deb ...
# Unpacking libsdl2-ttf-dev:amd64 (2.0.18+dfsg-2) ...
# Selecting previously unselected package python3-setuptools.
# Preparing to unpack .../57-python3-setuptools_59.6.0-1.2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-setuptools (59.6.0-1.2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../58-python3-wheel_0.37.1-2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../59-python3-pip_22.0.2+dfsg-1ubuntu0.3_all.deb ...
# Unpacking python3-pip (22.0.2+dfsg-1ubuntu0.3) ...
# Setting up libsdl2-image-2.0-0:amd64 (2.0.5+dfsg1-3build1) ...
# Setting up libglib2.0-dev-bin (2.72.4-0ubuntu2.2) ...
# Setting up libblkid-dev:amd64 (2.37.2-4ubuntu3) ...
# Setting up libmodplug1:amd64 (1:0.8.9.0-3) ...
# Setting up libsndio-dev:amd64 (1.8.1-1.1) ...
# Setting up libpciaccess-dev:amd64 (0.16-3) ...
# Setting up python3-setuptools (59.6.0-1.2ubuntu0.22.04.1) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up libice-dev:amd64 (2:1.0.10-1build2) ...
# Setting up libsm-dev:amd64 (2:1.2.3-1build2) ...
# Setting up libxxf86vm-dev:amd64 (1:1.1.4-1build3) ...
# Setting up libxkbcommon-dev:amd64 (1.4.0-1) ...
# Setting up libibus-1.0-5:amd64 (1.5.26-4) ...
# Setting up libffi-dev:amd64 (3.4.2-4) ...
# Setting up python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Setting up libgbm-dev:amd64 (23.0.4-0ubuntu1~22.04.1) ...
# Setting up libxfixes-dev:amd64 (1:6.0.0-1) ...
# Setting up libxv-dev:amd64 (2:1.0.11-1build2) ...
# Setting up libwayland-bin (1.20.0-1ubuntu0.1) ...
# Setting up libxrandr-dev:amd64 (2:1.5.2-1build1) ...
# Setting up libdbus-1-dev:amd64 (1.12.20-2ubuntu4.1) ...
# Setting up libxt-dev:amd64 (1:1.2.1-1) ...
# Setting up libpulse-mainloop-glib0:amd64 (1:15.99.1+dfsg1-1ubuntu2.1) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up libportmidi0:amd64 (1:217-6) ...
# Setting up libudev-dev:amd64 (249.11-0ubuntu3.9) ...
# Setting up libxinerama-dev:amd64 (2:1.1.4-3) ...
# Setting up libsepol-dev:amd64 (3.3-1build1) ...
# Setting up python3-pip (22.0.2+dfsg-1ubuntu0.3) ...
# Setting up libportmidi-dev (1:217-6) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libsdl2-ttf-2.0-0:amd64 (2.0.18+dfsg-2) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up libxi-dev:amd64 (2:1.8-1build1) ...
# Setting up timgm6mb-soundfont (1.3-5) ...
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf2/default-GM.sf2 (default-GM.sf2) in auto mode
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf3/default-GM.sf3 (default-GM.sf3) in auto mode
# Setting up gir1.2-ibus-1.0:amd64 (1.5.26-4) ...
# Setting up libopusfile0 (0.9+20170913-1.1build1) ...
# Setting up libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up libfluidsynth3:amd64 (2.2.5-1) ...
# Setting up libdrm-dev:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up libselinux1-dev:amd64 (3.3-1build2) ...
# Setting up libxcursor-dev:amd64 (1:1.2.0-2build4) ...
# Setting up libwayland-dev:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up libdecor-0-dev:amd64 (0.1.0-3build1) ...
# Setting up libsdl2-mixer-2.0-0:amd64 (2.0.4+dfsg1-4build1) ...
# Setting up libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up libmount-dev:amd64 (2.37.2-4ubuntu3) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up libglib2.0-dev:amd64 (2.72.4-0ubuntu2.2) ...
# Setting up libegl1-mesa-dev:amd64 (23.0.4-0ubuntu1~22.04.1) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Setting up libibus-1.0-dev:amd64 (1.5.26-4) ...
# Setting up libpulse-dev:amd64 (1:15.99.1+dfsg1-1ubuntu2.1) ...
# Setting up libsdl2-dev:amd64 (2.0.20+dfsg-2ubuntu1.22.04.1) ...
# Setting up libsdl2-ttf-dev:amd64 (2.0.18+dfsg-2) ...
# Setting up libsdl2-mixer-dev:amd64 (2.0.4+dfsg1-4build1) ...
# Setting up libsdl2-image-dev:amd64 (2.0.5+dfsg1-3build1) ...

# %%
# !sudo apt-get install -y \
    libgstreamer1.0 \
    gstreamer1.0-plugins-base \
    gstreamer1.0-plugins-good
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'libgstreamer1.0-dev' for regex 'libgstreamer1.0'
# Note, selecting 'libgstreamer1.0-0' for regex 'libgstreamer1.0'
# libgstreamer1.0-0 is already the newest version (1.20.3-0ubuntu1).
# libgstreamer1.0-0 set to manually installed.
# The following additional packages will be installed:
#   gir1.2-gstreamer-1.0 glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas gstreamer1.0-x libaa1
#   libcdparanoia0 libdv4 libdw-dev libelf-dev libgstreamer-plugins-good1.0-0
#   libgudev-1.0-0 libproxy1v5 libshout3 libsoup2.4-1 libsoup2.4-common
#   libtag1v5 libtag1v5-vanilla libunwind-dev libv4l-0 libv4lconvert0
#   libvisual-0.4-0 libwavpack1 session-migration
# Suggested packages:
#   gvfs libdv-bin oss-compat gstreamer1.0-doc libvisual-0.4-plugins
# The following NEW packages will be installed:
#   gir1.2-gstreamer-1.0 glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-x libaa1 libcdparanoia0 libdv4
#   libdw-dev libelf-dev libgstreamer-plugins-good1.0-0 libgstreamer1.0-dev
#   libgudev-1.0-0 libproxy1v5 libshout3 libsoup2.4-1 libsoup2.4-common
#   libtag1v5 libtag1v5-vanilla libunwind-dev libv4l-0 libv4lconvert0
#   libvisual-0.4-0 libwavpack1 session-migration
# 0 upgraded, 28 newly installed, 0 to remove and 16 not upgraded.
# Need to get 7,043 kB of archives.
# After this operation, 29.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-gstreamer-1.0 amd64 1.20.3-0ubuntu1 [87.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libproxy1v5 amd64 0.4.17-2 [51.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking-common all 2.72.0-1 [3,718 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking-services amd64 2.72.0-1 [9,982 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking amd64 2.72.0-1 [69.8 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdparanoia0 amd64 3.10.2+debian-14build2 [49.3 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisual-0.4-0 amd64 0.4.0-17build2 [108 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-base amd64 1.20.1-1ubuntu0.1 [712 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libaa1 amd64 1.4p5-50build1 [51.9 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdv4 amd64 1.0.0-14build1 [61.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-good1.0-0 amd64 1.20.3-0ubuntu1.1 [30.0 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libshout3 amd64 2.4.5-1build3 [54.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtag1v5-vanilla amd64 1.11.1+dfsg.1-3ubuntu3 [304 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtag1v5 amd64 1.11.1+dfsg.1-3ubuntu3 [11.5 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libv4lconvert0 amd64 1.22.1-2build1 [82.4 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libv4l-0 amd64 1.22.1-2build1 [44.9 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwavpack1 amd64 5.4.0-1build2 [83.7 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsoup2.4-common all 2.74.2-3 [4,008 B]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsoup2.4-1 amd64 2.74.2-3 [287 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-good amd64 1.20.3-0ubuntu1.1 [2,008 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-x amd64 1.20.1-1ubuntu0.1 [85.1 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libelf-dev amd64 0.186-1build1 [64.4 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdw-dev amd64 0.186-1build1 [327 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libunwind-dev amd64 1.3.2-2build2.1 [1,883 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer1.0-dev amd64 1.20.3-0ubuntu1 [510 kB]
# Fetched 7,043 kB in 3s (2,289 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 28.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package gir1.2-gstreamer-1.0:amd64.
# (Reading database ... 123750 files and directories currently installed.)
# Preparing to unpack .../00-gir1.2-gstreamer-1.0_1.20.3-0ubuntu1_amd64.deb ...
# Unpacking gir1.2-gstreamer-1.0:amd64 (1.20.3-0ubuntu1) ...
# Selecting previously unselected package libproxy1v5:amd64.
# Preparing to unpack .../01-libproxy1v5_0.4.17-2_amd64.deb ...
# Unpacking libproxy1v5:amd64 (0.4.17-2) ...
# Selecting previously unselected package glib-networking-common.
# Preparing to unpack .../02-glib-networking-common_2.72.0-1_all.deb ...
# Unpacking glib-networking-common (2.72.0-1) ...
# Selecting previously unselected package glib-networking-services.
# Preparing to unpack .../03-glib-networking-services_2.72.0-1_amd64.deb ...
# Unpacking glib-networking-services (2.72.0-1) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../04-session-migration_0.3.6_amd64.deb ...
# Unpacking session-migration (0.3.6) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../05-gsettings-desktop-schemas_42.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Selecting previously unselected package glib-networking:amd64.
# Preparing to unpack .../06-glib-networking_2.72.0-1_amd64.deb ...
# Unpacking glib-networking:amd64 (2.72.0-1) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../07-libcdparanoia0_3.10.2+debian-14build2_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../08-libvisual-0.4-0_0.4.0-17build2_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../09-gstreamer1.0-plugins-base_1.20.1-1ubuntu0.1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.1) ...
# Selecting previously unselected package libaa1:amd64.
# Preparing to unpack .../10-libaa1_1.4p5-50build1_amd64.deb ...
# Unpacking libaa1:amd64 (1.4p5-50build1) ...
# Selecting previously unselected package libdv4:amd64.
# Preparing to unpack .../11-libdv4_1.0.0-14build1_amd64.deb ...
# Unpacking libdv4:amd64 (1.0.0-14build1) ...
# Selecting previously unselected package libgstreamer-plugins-good1.0-0:amd64.
# Preparing to unpack .../12-libgstreamer-plugins-good1.0-0_1.20.3-0ubuntu1.1_amd64.deb ...
# Unpacking libgstreamer-plugins-good1.0-0:amd64 (1.20.3-0ubuntu1.1) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../13-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libshout3:amd64.
# Preparing to unpack .../14-libshout3_2.4.5-1build3_amd64.deb ...
# Unpacking libshout3:amd64 (2.4.5-1build3) ...
# Selecting previously unselected package libtag1v5-vanilla:amd64.
# Preparing to unpack .../15-libtag1v5-vanilla_1.11.1+dfsg.1-3ubuntu3_amd64.deb ...
# Unpacking libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Selecting previously unselected package libtag1v5:amd64.
# Preparing to unpack .../16-libtag1v5_1.11.1+dfsg.1-3ubuntu3_amd64.deb ...
# Unpacking libtag1v5:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Selecting previously unselected package libv4lconvert0:amd64.
# Preparing to unpack .../17-libv4lconvert0_1.22.1-2build1_amd64.deb ...
# Unpacking libv4lconvert0:amd64 (1.22.1-2build1) ...
# Selecting previously unselected package libv4l-0:amd64.
# Preparing to unpack .../18-libv4l-0_1.22.1-2build1_amd64.deb ...
# Unpacking libv4l-0:amd64 (1.22.1-2build1) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../19-libwavpack1_5.4.0-1build2_amd64.deb ...
# Unpacking libwavpack1:amd64 (5.4.0-1build2) ...
# Selecting previously unselected package libsoup2.4-common.
# Preparing to unpack .../20-libsoup2.4-common_2.74.2-3_all.deb ...
# Unpacking libsoup2.4-common (2.74.2-3) ...
# Selecting previously unselected package libsoup2.4-1:amd64.
# Preparing to unpack .../21-libsoup2.4-1_2.74.2-3_amd64.deb ...
# Unpacking libsoup2.4-1:amd64 (2.74.2-3) ...
# Selecting previously unselected package gstreamer1.0-plugins-good:amd64.
# Preparing to unpack .../22-gstreamer1.0-plugins-good_1.20.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-good:amd64 (1.20.3-0ubuntu1.1) ...
# Selecting previously unselected package gstreamer1.0-x:amd64.
# Preparing to unpack .../23-gstreamer1.0-x_1.20.1-1ubuntu0.1_amd64.deb ...
# Unpacking gstreamer1.0-x:amd64 (1.20.1-1ubuntu0.1) ...
# Selecting previously unselected package libelf-dev:amd64.
# Preparing to unpack .../24-libelf-dev_0.186-1build1_amd64.deb ...
# Unpacking libelf-dev:amd64 (0.186-1build1) ...
# Selecting previously unselected package libdw-dev:amd64.
# Preparing to unpack .../25-libdw-dev_0.186-1build1_amd64.deb ...
# Unpacking libdw-dev:amd64 (0.186-1build1) ...
# Selecting previously unselected package libunwind-dev:amd64.
# Preparing to unpack .../26-libunwind-dev_1.3.2-2build2.1_amd64.deb ...
# Unpacking libunwind-dev:amd64 (1.3.2-2build2.1) ...
# Selecting previously unselected package libgstreamer1.0-dev:amd64.
# Preparing to unpack .../27-libgstreamer1.0-dev_1.20.3-0ubuntu1_amd64.deb ...
# Unpacking libgstreamer1.0-dev:amd64 (1.20.3-0ubuntu1) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Setting up gir1.2-gstreamer-1.0:amd64 (1.20.3-0ubuntu1) ...
# Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up libproxy1v5:amd64 (0.4.17-2) ...
# Setting up libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Setting up gstreamer1.0-x:amd64 (1.20.1-1ubuntu0.1) ...
# Setting up libunwind-dev:amd64 (1.3.2-2build2.1) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Setting up libgstreamer-plugins-good1.0-0:amd64 (1.20.3-0ubuntu1.1) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.1) ...
# Setting up libshout3:amd64 (2.4.5-1build3) ...
# Setting up libelf-dev:amd64 (0.186-1build1) ...
# Setting up libsoup2.4-common (2.74.2-3) ...
# Setting up libtag1v5:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Setting up libdv4:amd64 (1.0.0-14build1) ...
# Setting up libwavpack1:amd64 (5.4.0-1build2) ...
# Setting up libv4lconvert0:amd64 (1.22.1-2build1) ...
# Setting up glib-networking-common (2.72.0-1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up libaa1:amd64 (1.4p5-50build1) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up glib-networking-services (2.72.0-1) ...
# Setting up libdw-dev:amd64 (0.186-1build1) ...
# Setting up libv4l-0:amd64 (1.22.1-2build1) ...
# Setting up libgstreamer1.0-dev:amd64 (1.20.3-0ubuntu1) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Setting up glib-networking:amd64 (2.72.0-1) ...
# Setting up libsoup2.4-1:amd64 (2.74.2-3) ...
# Setting up gstreamer1.0-plugins-good:amd64 (1.20.3-0ubuntu1.1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link

# %%
# !sudo apt-get install build-essential libsqlite3-dev sqlite3 bzip2 libbz2-dev zlib1g-dev libssl-dev openssl libgdbm-dev libgdbm-compat-dev liblzma-dev libreadline-dev libncursesw5-dev libffi-dev uuid-dev libffi6
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package libffi6

# %%
# !sudo apt-get install libffi-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libffi-dev is already the newest version (3.4.2-4).
# libffi-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.

# %%
# !buildozer init
# Out:
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? y
# File buildozer.spec created, ready to customize!

# %%
# !pip install kivy
# !pip install firebase_admin
# Out:
# Collecting kivy
#   Downloading Kivy-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.9/18.9 MB 53.7 MB/s eta 0:00:00
# Collecting Kivy-Garden>=0.1.4 (from kivy)
#   Downloading Kivy_Garden-0.1.5-py3-none-any.whl (4.6 kB)
# Requirement already satisfied: docutils in /usr/local/lib/python3.10/dist-packages (from kivy) (0.18.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from kivy) (2.16.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from Kivy-Garden>=0.1.4->kivy) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->Kivy-Garden>=0.1.4->kivy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->Kivy-Garden>=0.1.4->kivy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->Kivy-Garden>=0.1.4->kivy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->Kivy-Garden>=0.1.4->kivy) (2023.7.22)
# Installing collected packages: Kivy-Garden, kivy
# Successfully installed Kivy-Garden-0.1.5 kivy-2.2.1
# Requirement already satisfied: firebase_admin in /usr/local/lib/python3.10/dist-packages (5.3.0)
# Requirement already satisfied: cachecontrol>=0.12.6 in /usr/local/lib/python3.10/dist-packages (from firebase_admin) (0.13.1)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /usr/local/lib/python3.10/dist-packages (from firebase_admin) (2.84.0)
# Requirement already satisfied: google-cloud-storage>=1.37.1 in /usr/local/lib/python3.10/dist-packages (from firebase_admin) (2.8.0)
# Requirement already satisfied: google-api-core[grpc]<3.0.0dev,>=1.22.1 in /usr/local/lib/python3.10/dist-packages (from firebase_admin) (2.11.1)
# Requirement already satisfied: google-cloud-firestore>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from firebase_admin) (2.11.1)
# Requirement already satisfied: requests>=2.16.0 in /usr/local/lib/python3.10/dist-packages (from cachecontrol>=0.12.6->firebase_admin) (2.31.0)
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from cachecontrol>=0.12.6->firebase_admin) (1.0.5)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (1.60.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (3.20.3)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (2.17.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (1.57.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (1.48.2)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.7.8->firebase_admin) (0.22.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.7.8->firebase_admin) (0.1.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.7.8->firebase_admin) (4.1.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-firestore>=2.1.0->firebase_admin) (2.3.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-firestore>=2.1.0->firebase_admin) (1.22.3)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage>=1.37.1->firebase_admin) (2.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage>=1.37.1->firebase_admin) (1.5.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.15.0->google-api-python-client>=1.7.8->firebase_admin) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase_admin) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase_admin) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase_admin) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase_admin) (2023.7.22)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (0.5.0)

# %%
# !sudo apt-get install libtool
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   libtool-doc gcj-jdk
# The following NEW packages will be installed:
#   libtool
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 164 kB of archives.
# After this operation, 1,227 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtool all 2.4.6-15build2 [164 kB]
# Fetched 164 kB in 0s (425 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libtool.
# (Reading database ... 120831 files and directories currently installed.)
# Preparing to unpack .../libtool_2.4.6-15build2_all.deb ...
# Unpacking libtool (2.4.6-15build2) ...
# Setting up libtool (2.4.6-15build2) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !buildozer -v android debug deploy run
# Out:
# Streaming output truncated to the last 5000 lines.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/poly1305/poly1305_ameth.d.tmp -MT crypto/poly1305/poly1305_ameth.o -c -o crypto/poly1305/poly1305_ameth.o crypto/poly1305/poly1305_ameth.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/poly1305/poly1305_pmeth.d.tmp -MT crypto/poly1305/poly1305_pmeth.o -c -o crypto/poly1305/poly1305_pmeth.o crypto/poly1305/poly1305_pmeth.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -Icrypto/modes -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rand/drbg_ctr.d.tmp -MT crypto/rand/drbg_ctr.o -c -o crypto/rand/drbg_ctr.o crypto/rand/drbg_ctr.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rand/drbg_lib.d.tmp -MT crypto/rand/drbg_lib.o -c -o crypto/rand/drbg_lib.o crypto/rand/drbg_lib.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rand/rand_egd.d.tmp -MT crypto/rand/rand_egd.o -c -o crypto/rand/rand_egd.o crypto/rand/rand_egd.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rand/rand_err.d.tmp -MT crypto/rand/rand_err.o -c -o crypto/rand/rand_err.o crypto/rand/rand_err.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rand/rand_lib.d.tmp -MT crypto/rand/rand_lib.o -c -o crypto/rand/rand_lib.o crypto/rand/rand_lib.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rand/rand_unix.d.tmp -MT crypto/rand/rand_unix.o -c -o crypto/rand/rand_unix.o crypto/rand/rand_unix.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rand/rand_vms.d.tmp -MT crypto/rand/rand_vms.o -c -o crypto/rand/rand_vms.o crypto/rand/rand_vms.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rand/rand_win.d.tmp -MT crypto/rand/rand_win.o -c -o crypto/rand/rand_win.o crypto/rand/rand_win.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rand/randfile.d.tmp -MT crypto/rand/randfile.o -c -o crypto/rand/randfile.o crypto/rand/randfile.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rc2/rc2_cbc.d.tmp -MT crypto/rc2/rc2_cbc.o -c -o crypto/rc2/rc2_cbc.o crypto/rc2/rc2_cbc.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rc2/rc2_ecb.d.tmp -MT crypto/rc2/rc2_ecb.o -c -o crypto/rc2/rc2_ecb.o crypto/rc2/rc2_ecb.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rc2/rc2_skey.d.tmp -MT crypto/rc2/rc2_skey.o -c -o crypto/rc2/rc2_skey.o crypto/rc2/rc2_skey.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rc2/rc2cfb64.d.tmp -MT crypto/rc2/rc2cfb64.o -c -o crypto/rc2/rc2cfb64.o crypto/rc2/rc2cfb64.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rc2/rc2ofb64.d.tmp -MT crypto/rc2/rc2ofb64.o -c -o crypto/rc2/rc2ofb64.o crypto/rc2/rc2ofb64.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rc4/rc4_enc.d.tmp -MT crypto/rc4/rc4_enc.o -c -o crypto/rc4/rc4_enc.o crypto/rc4/rc4_enc.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rc4/rc4_skey.d.tmp -MT crypto/rc4/rc4_skey.o -c -o crypto/rc4/rc4_skey.o crypto/rc4/rc4_skey.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/ripemd/rmd_dgst.d.tmp -MT crypto/ripemd/rmd_dgst.o -c -o crypto/ripemd/rmd_dgst.o crypto/ripemd/rmd_dgst.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/ripemd/rmd_one.d.tmp -MT crypto/ripemd/rmd_one.o -c -o crypto/ripemd/rmd_one.o crypto/ripemd/rmd_one.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_ameth.d.tmp -MT crypto/rsa/rsa_ameth.o -c -o crypto/rsa/rsa_ameth.o crypto/rsa/rsa_ameth.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_asn1.d.tmp -MT crypto/rsa/rsa_asn1.o -c -o crypto/rsa/rsa_asn1.o crypto/rsa/rsa_asn1.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_chk.d.tmp -MT crypto/rsa/rsa_chk.o -c -o crypto/rsa/rsa_chk.o crypto/rsa/rsa_chk.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_crpt.d.tmp -MT crypto/rsa/rsa_crpt.o -c -o crypto/rsa/rsa_crpt.o crypto/rsa/rsa_crpt.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_depr.d.tmp -MT crypto/rsa/rsa_depr.o -c -o crypto/rsa/rsa_depr.o crypto/rsa/rsa_depr.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_err.d.tmp -MT crypto/rsa/rsa_err.o -c -o crypto/rsa/rsa_err.o crypto/rsa/rsa_err.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_gen.d.tmp -MT crypto/rsa/rsa_gen.o -c -o crypto/rsa/rsa_gen.o crypto/rsa/rsa_gen.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_lib.d.tmp -MT crypto/rsa/rsa_lib.o -c -o crypto/rsa/rsa_lib.o crypto/rsa/rsa_lib.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_meth.d.tmp -MT crypto/rsa/rsa_meth.o -c -o crypto/rsa/rsa_meth.o crypto/rsa/rsa_meth.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_mp.d.tmp -MT crypto/rsa/rsa_mp.o -c -o crypto/rsa/rsa_mp.o crypto/rsa/rsa_mp.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_none.d.tmp -MT crypto/rsa/rsa_none.o -c -o crypto/rsa/rsa_none.o crypto/rsa/rsa_none.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_oaep.d.tmp -MT crypto/rsa/rsa_oaep.o -c -o crypto/rsa/rsa_oaep.o crypto/rsa/rsa_oaep.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_ossl.d.tmp -MT crypto/rsa/rsa_ossl.o -c -o crypto/rsa/rsa_ossl.o crypto/rsa/rsa_ossl.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_pk1.d.tmp -MT crypto/rsa/rsa_pk1.o -c -o crypto/rsa/rsa_pk1.o crypto/rsa/rsa_pk1.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_pmeth.d.tmp -MT crypto/rsa/rsa_pmeth.o -c -o crypto/rsa/rsa_pmeth.o crypto/rsa/rsa_pmeth.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_prn.d.tmp -MT crypto/rsa/rsa_prn.o -c -o crypto/rsa/rsa_prn.o crypto/rsa/rsa_prn.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_pss.d.tmp -MT crypto/rsa/rsa_pss.o -c -o crypto/rsa/rsa_pss.o crypto/rsa/rsa_pss.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_saos.d.tmp -MT crypto/rsa/rsa_saos.o -c -o crypto/rsa/rsa_saos.o crypto/rsa/rsa_saos.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_sign.d.tmp -MT crypto/rsa/rsa_sign.o -c -o crypto/rsa/rsa_sign.o crypto/rsa/rsa_sign.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_ssl.d.tmp -MT crypto/rsa/rsa_ssl.o -c -o crypto/rsa/rsa_ssl.o crypto/rsa/rsa_ssl.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_x931.d.tmp -MT crypto/rsa/rsa_x931.o -c -o crypto/rsa/rsa_x931.o crypto/rsa/rsa_x931.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/rsa/rsa_x931g.d.tmp -MT crypto/rsa/rsa_x931g.o -c -o crypto/rsa/rsa_x931g.o crypto/rsa/rsa_x931g.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/seed/seed.d.tmp -MT crypto/seed/seed.o -c -o crypto/seed/seed.o crypto/seed/seed.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a/include/python3.1 -MMD -MF crypto/seed/seed_cbc.d.tmp -MT crypto/seed/seed_cbc.o -c -o crypto/seed/seed_cbc.o crypto/seed/seed_cbc.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# ...
# [DEBUG]:   	                                                     ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	[armeabi-v7a] SharedLibrary  : libmain.so
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/bin/clang++ -Wl,--gc-sections -Wl,-soname,libmain.so -shared /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/bootstrap_builds/sdl2/obj/local/armeabi-v7a/objs-debug/main/__/__/SDL/src/main/android/SDL_android_main.o /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/bootstrap_builds/sdl2/obj/local/armeabi-v7a/objs-debug/main/start.o -latomic /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/bootstrap_builds/sdl2/obj/local/armeabi-v7a/libSDL2.so -target armv7-none-linux-androideabi21 -no-canonical-prefixes   -Wl,--build-id=sha1 -Wl,--no-rosegment  -L/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_21/python3/android-build -stdlib=libstdc++ -Wl,--no-undefined -Wl,--fatal-warnings -lGLESv1_CM -lGLESv2 -llog -lpython3.10 -ldl -lc -lm -o /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/bootstrap_builds/sdl2/obj/local/armeabi-v7a/libmain.so
# [DEBUG]:   	[armeabi-v7a] Install        : libmain.so => libs/armeabi-v7a/libmain.so
# [DEBUG]:   	install -p /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/bootstrap_builds/sdl2/obj/local/armeabi-v7a/libmain.so /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/bootstrap_builds/sdl2/libs/armeabi-v7a/libmain.so
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    Building setuptools for armeabi-v7a
# [INFO]:    setuptools apparently isn't already in site-packages
# [INFO]:    Installing setuptools into site-packages
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/setuptools/armeabi-v7a__ndk_target_21/setuptools
# [DEBUG]:   -> running python3 setup.py install -O2 --root=/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a --install-lib=.
# [DEBUG]:   	Traceback (most recent call last):
# [DEBUG]:   	  File "/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/setuptools/armeabi-v7a__ndk_target_21/setuptools/setup.py", line 7, in <module>
# [DEBUG]:   	    import setuptools
# [DEBUG]:   	  File "/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/setuptools/armeabi-v7a__ndk_target_21/setuptools/setuptools/__init__.py", line 18, in <module>
# [DEBUG]:   	    from setuptools.dist import Distribution
# [DEBUG]:   	  File "/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/setuptools/armeabi-v7a__ndk_target_21/setuptools/setuptools/dist.py", line 32, in <module>
# [DEBUG]:   	    from setuptools import windows_support
# [DEBUG]:   	  File "/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/setuptools/armeabi-v7a__ndk_target_21/setuptools/setuptools/windows_support.py", line 2, in <module>
# [DEBUG]:   	    import ctypes
# [DEBUG]:   	  File "/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/hostpython3/desktop/hostpython3/Lib/ctypes/__init__.py", line 8, in <module>
# [DEBUG]:   	    from _ctypes import Union, Structure, Array
# [DEBUG]:   	ModuleNotFoundError: No module named '_ctypes'
# Exception in thread background thread for pid 87550:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/.local/lib/python3.10/site-packages/sh.py", line 1641, in wrap
#     fn(*rgs, **kwargs)
#   File "/root/.local/lib/python3.10/site-packages/sh.py", line 2569, in background_thread
#     handle_exit_code(exit_code)
#   File "/root/.local/lib/python3.10/site-packages/sh.py", line 2269, in fn
#     return self.command.handle_command_exit_code(exit_code)
#   File "/root/.local/lib/python3.10/site-packages/sh.py", line 869, in handle_command_exit_code
#     raise exc
# sh.ErrorReturnCode_1:
#
#   RAN: /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/hostpython3/desktop/hostpython3/native-build/python3 setup.py install -O2 --root=/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a --install-lib=.
#
#   STDOUT:
# Traceback (most recent call last):
#   File "/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/setuptools/armeabi-v7a__ndk_target_21/setuptools/setup.py", line 7, in <module>
#     import setuptools
#   File "/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/setuptools/armeabi-v7a__ndk_target_21/setuptools/setuptools/__init__.py", line 18, in <module>
#     from setuptools.dist import Distribution
#   File "/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/setuptools/armeabi-v7a__ndk_target_21/setuptools/setuptools/dist.py", line 32, in <module>
#     from setuptools import windows_support
#   File "/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/setuptools/armeabi-v7a__ndk_target_21/setuptools/setuptools/windows_support.py", line 2, in <module>
#     import ctypes
#   File "/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/hostpython3/desktop/hostpython3/Lib/ctypes/__init__.py", line 8, in <module>
#     from _ctypes import Union, Structure, Array
# ModuleNotFoundError: No module named '_ctypes'
#
#
#   STDERR:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/.buildozer/android/platform/python-for-android/pythonforandroid/toolchain.py", line 1312, in <module>
#     main()
#   File "/content/.buildozer/android/platform/python-for-android/pythonforandroid/entrypoints.py", line 18, in main
#     ToolchainCL()
#   File "/content/.buildozer/android/platform/python-for-android/pythonforandroid/toolchain.py", line 734, in __init__
#     getattr(self, command)(args)
#   File "/content/.buildozer/android/platform/python-for-android/pythonforandroid/toolchain.py", line 153, in wrapper_func
#     build_dist_from_args(ctx, dist, args)
#   File "/content/.buildozer/android/platform/python-for-android/pythonforandroid/toolchain.py", line 212, in build_dist_from_args
#     build_recipes(build_order, python_modules, ctx,
#   File "/content/.buildozer/android/platform/python-for-android/pythonforandroid/build.py", line 504, in build_recipes
#     recipe.build_arch(arch)
#   File "/content/.buildozer/android/platform/python-for-android/pythonforandroid/recipe.py", line 934, in build_arch
#     self.install_python_package(arch)
#   File "/content/.buildozer/android/platform/python-for-android/pythonforandroid/recipe.py", line 950, in install_python_package
#     shprint(hostpython, 'setup.py', 'install', '-O2',
#   File "/content/.buildozer/android/platform/python-for-android/pythonforandroid/logger.py", line 167, in shprint
#     for line in output:
#   File "/root/.local/lib/python3.10/site-packages/sh.py", line 915, in next
#     self.wait()
#   File "/root/.local/lib/python3.10/site-packages/sh.py", line 845, in wait
#     self.handle_command_exit_code(exit_code)
#   File "/root/.local/lib/python3.10/site-packages/sh.py", line 869, in handle_command_exit_code
#     raise exc
# sh.ErrorReturnCode_1:
#
#   RAN: /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/hostpython3/desktop/hostpython3/native-build/python3 setup.py install -O2 --root=/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myapp/armeabi-v7a --install-lib=.
#
#   STDOUT:
# Traceback (most recent call last):
#   File "/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/setuptools/armeabi-v7a__ndk_target_21/setuptools/setup.py", line 7, in <module>
#     import setuptools
#   File "/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/setuptools/armeabi-v7a__ndk_target_21/setuptools/setuptools/__init__.py", line 18, in <module>
#     from setuptools.dist import Distribution
#   File "/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/setuptools/armeabi-v7a__ndk_target_21/setuptools/setuptools/dist.py", line 32, in <module>
#     from setuptools import windows_support
#   File "/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/setuptools/armeabi-v7a__ndk_target_21/setuptools/setuptools/windows_support.py", line 2, in <module>
#     import ctypes
#   File "/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/hostpython3/desktop/hostpython3/Lib/ctypes/__init__.py", line 8, in <module>
#     from _ctypes import Union, Structure, Array
# ModuleNotFoundError: No module named '_ctypes'
#
#
#   STDERR:
#
# # Command failed: ['/usr/bin/python3', '-m', 'pythonforandroid.toolchain', 'create', '--dist_name=myapp', '--bootstrap=sdl2', '--requirements=python3,kivy', '--arch=arm64-v8a', '--arch=armeabi-v7a', '--copy-libs', '--color=always', '--storage-dir=/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a', '--ndk-api=21', '--ignore-setup-py', '--debug']
# # ENVIRONMENT:
# #     SHELL = '/bin/bash'
# #     NV_LIBCUBLAS_VERSION = '11.11.3.6-1'
# #     NVIDIA_VISIBLE_DEVICES = 'all'
# #     COLAB_JUPYTER_TRANSPORT = 'ipc'
# #     NV_NVML_DEV_VERSION = '11.8.86-1'
# #     NV_CUDNN_PACKAGE_NAME = 'libcudnn8'
# #     CGROUP_MEMORY_EVENTS = '/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events'
# #     NV_LIBNCCL_DEV_PACKAGE = 'libnccl-dev=2.15.5-1+cuda11.8'
# #     NV_LIBNCCL_DEV_PACKAGE_VERSION = '2.15.5-1'
# #     VM_GCE_METADATA_HOST = '169.254.169.253'
# #     HOSTNAME = '1c4f5c77ae63'
# #     LANGUAGE = 'en_US'
# #     TBE_RUNTIME_ADDR = '172.28.0.1:8011'
# #     GCE_METADATA_TIMEOUT = '3'
# #     NVIDIA_REQUIRE_CUDA = ('cuda>=11.8 brand=tesla,driver>=450,driver<451 '
#  'brand=tesla,driver>=470,driver<471 brand=unknown,driver>=470,driver<471 '
#  'brand=nvidia,driver>=470,driver<471 brand=nvidiartx,driver>=470,driver<471 '
#  'brand=geforce,driver>=470,driver<471 brand=geforcertx,driver>=470,driver<471 '
#  'brand=quadro,driver>=470,driver<471 brand=quadrortx,driver>=470,driver<471 '
#  'brand=titan,driver>=470,driver<471 brand=titanrtx,driver>=470,driver<471 '
#  'brand=tesla,driver>=510,driver<511 brand=unknown,driver>=510,driver<511 '
#  'brand=nvidia,driver>=510,driver<511 brand=nvidiartx,driver>=510,driver<511 '
#  'brand=geforce,driver>=510,driver<511 brand=geforcertx,driver>=510,driver<511 '
#  'brand=quadro,driver>=510,driver<511 brand=quadrortx,driver>=510,driver<511 '
#  'brand=titan,driver>=510,driver<511 brand=titanrtx,driver>=510,driver<511 '
#  'brand=tesla,driver>=515,driver<516 brand=unknown,driver>=515,driver<516 '
#  'brand=nvidia,driver>=515,driver<516 brand=nvidiartx,driver>=515,driver<516 '
#  'brand=geforce,driver>=515,driver<516 brand=geforcertx,driver>=515,driver<516 '
#  'brand=quadro,driver>=515,driver<516 brand=quadrortx,driver>=515,driver<516 '
#  'brand=titan,driver>=515,driver<516 brand=titanrtx,driver>=515,driver<516')
# #     NV_LIBCUBLAS_DEV_PACKAGE = 'libcublas-dev-11-8=11.11.3.6-1'
# #     NV_NVTX_VERSION = '11.8.86-1'
# #     COLAB_JUPYTER_IP = '172.28.0.12'
# #     NV_CUDA_CUDART_DEV_VERSION = '11.8.89-1'
# #     NV_LIBCUSPARSE_VERSION = '11.7.5.86-1'
# #     COLAB_LANGUAGE_SERVER_PROXY_ROOT_URL = 'http://172.28.0.1:8013/'
# #     NV_LIBNPP_VERSION = '11.8.0.86-1'
# #     NCCL_VERSION = '2.15.5-1'
# #     KMP_LISTEN_PORT = '6000'
# #     TF_FORCE_GPU_ALLOW_GROWTH = 'true'
# #     ENV = '/root/.bashrc'
# #     PWD = '/content'
# #     TBE_EPHEM_CREDS_ADDR = '172.28.0.1:8009'
# #     COLAB_LANGUAGE_SERVER_PROXY_REQUEST_TIMEOUT = '30s'
# #     TBE_CREDS_ADDR = '172.28.0.1:8008'
# #     NV_CUDNN_PACKAGE = 'libcudnn8=8.9.0.131-1+cuda11.8'
# #     NVIDIA_DRIVER_CAPABILITIES = 'compute,utility'
# #     COLAB_JUPYTER_TOKEN = ''
# #     LAST_FORCED_REBUILD = '20230808'
# #     NV_NVPROF_DEV_PACKAGE = 'cuda-nvprof-11-8=11.8.87-1'
# #     NV_LIBNPP_PACKAGE = 'libnpp-11-8=11.8.0.86-1'
# #     NV_LIBNCCL_DEV_PACKAGE_NAME = 'libnccl-dev'
# #     TCLLIBPATH = '/usr/share/tcltk/tcllib1.20'
# #     NV_LIBCUBLAS_DEV_VERSION = '11.11.3.6-1'
# #     COLAB_KERNEL_MANAGER_PROXY_HOST = '172.28.0.12'
# #     NVIDIA_PRODUCT_NAME = 'CUDA'
# #     NV_LIBCUBLAS_DEV_PACKAGE_NAME = 'libcublas-dev-11-8'
# #     USE_AUTH_EPHEM = '1'
# #     NV_CUDA_CUDART_VERSION = '11.8.89-1'
# #     HOME = '/root'
# #     LANG = 'en_US.UTF-8'
# #     CUDA_VERSION = '11.8.0'
# #     CLOUDSDK_CONFIG = '/content/.config'
# #     NV_LIBCUBLAS_PACKAGE = 'libcublas-11-8=11.11.3.6-1'
# #     NV_CUDA_NSIGHT_COMPUTE_DEV_PACKAGE = 'cuda-nsight-compute-11-8=11.8.0-1'
# #     COLAB_RELEASE_TAG = 'release-colab-20230822-060133-RC00'
# #     PYDEVD_USE_FRAME_EVAL = 'NO'
# #     KMP_TARGET_PORT = '9000'
# #     CLICOLOR = '1'
# #     KMP_EXTRA_ARGS = ('--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 '
#  '--tunnel_background_save_url=https://colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/m-s-1npm4otpzrpem '
#  '--tunnel_background_save_delay=10s '
#  '--tunnel_periodic_background_save_frequency=30m0s '
#  '--enable_output_coalescing=true --output_coalescing_required=true')
# #     NV_LIBNPP_DEV_PACKAGE = 'libnpp-dev-11-8=11.8.0.86-1'
# #     NV_LIBCUBLAS_PACKAGE_NAME = 'libcublas-11-8'
# #     COLAB_KERNEL_MANAGER_PROXY_PORT = '6000'
# #     CLOUDSDK_PYTHON = 'python3'
# #     NV_LIBNPP_DEV_VERSION = '11.8.0.86-1'
# #     ENABLE_DIRECTORYPREFETCHER = '1'
# #     NO_GCE_CHECK = 'False'
# #     JPY_PARENT_PID = '79'
# #     PYTHONPATH = '/env/python'
# #     TERM = 'xterm-color'
# #     NV_LIBCUSPARSE_DEV_VERSION = '11.7.5.86-1'
# #     GIT_PAGER = 'cat'
# #     LIBRARY_PATH = '/usr/local/cuda/lib64/stubs'
# #     NV_CUDNN_VERSION = '8.9.0.131'
# #     SHLVL = '0'
# #     PAGER = 'cat'
# #     COLAB_LANGUAGE_SERVER_PROXY = '/usr/colab/bin/language_service'
# #     NV_CUDA_LIB_VERSION = '11.8.0-1'
# #     NVARCH = 'x86_64'
# #     NV_CUDNN_PACKAGE_DEV = 'libcudnn8-dev=8.9.0.131-1+cuda11.8'
# #     NV_CUDA_COMPAT_PACKAGE = 'cuda-compat-11-8'
# #     MPLBACKEND = 'module://ipykernel.pylab.backend_inline'
# #     NV_LIBNCCL_PACKAGE = 'libnccl2=2.15.5-1+cuda11.8'
# #     LD_LIBRARY_PATH = '/usr/local/nvidia/lib:/usr/local/nvidia/lib64'
# #     COLAB_GPU = ''
# #     GCS_READ_CACHE_BLOCK_SIZE_MB = '16'
# #     NV_CUDA_NSIGHT_COMPUTE_VERSION = '11.8.0-1'
# #     NV_NVPROF_VERSION = '11.8.87-1'
# #     LC_ALL = 'en_US.UTF-8'
# #     COLAB_FILE_HANDLER_ADDR = 'localhost:3453'
# #     PATH = '/root/.buildozer/android/platform/apache-ant-1.9.4/bin:/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin'
# #     NV_LIBNCCL_PACKAGE_NAME = 'libnccl2'
# #     COLAB_DEBUG_ADAPTER_MUX_PATH = '/usr/local/bin/dap_multiplexer'
# #     NV_LIBNCCL_PACKAGE_VERSION = '2.15.5-1'
# #     PYTHONWARNINGS = 'ignore:::pip._internal.cli.base_command'
# #     DEBIAN_FRONTEND = 'noninteractive'
# #     COLAB_BACKEND_VERSION = 'next'
# #     OLDPWD = '/'
# #     _ = '/usr/local/bin/buildozer'
# #     PACKAGES_PATH = '/root/.buildozer/android/packages'
# #     ANDROIDSDK = '/root/.buildozer/android/platform/android-sdk'
# #     ANDROIDNDK = '/root/.buildozer/android/platform/android-ndk-r25b'
# #     ANDROIDAPI = '31'
# #     ANDROIDMINAPI = '21'
# #
# # Buildozer failed to execute the last command
# # The error might be hidden in the log above this error
# # Please read the full log, and search for it before
# # raising an issue with buildozer itself.
# # In case of a bug report, please add a full log with log_level = 2

# %%
# !buildozer android clean
# Out:
# # Check configuration tokens
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? y
# # Ensure build layout
# # Check configuration tokens
# # Run ['/usr/bin/python3', '-m', 'pythonforandroid.toolchain', 'clean_builds', '--color=always', '--storage-dir=/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a', '--ndk-api=21', '--ignore-setup-py', '--debug']
# # Cwd /content/.buildozer/android/platform/python-for-android
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.
# /content/.buildozer/android/platform/python-for-android/pythonforandroid/toolchain.py:59: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(cur_ver) < LooseVersion(version):
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.
# # Run ['/usr/bin/python3', '-m', 'pythonforandroid.toolchain', 'clean_dists', '--color=always', '--storage-dir=/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a', '--ndk-api=21', '--ignore-setup-py', '--debug']
# # Cwd /content/.buildozer/android/platform/python-for-android
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.
# /content/.buildozer/android/platform/python-for-android/pythonforandroid/toolchain.py:59: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(cur_ver) < LooseVersion(version):
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.

# %%
# !pip uninstall cython
# !sudo pip install cython
# Out:
# WARNING: Skipping cython as it is not installed.
# Collecting cython
#   Downloading Cython-3.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 20.7 MB/s eta 0:00:00
# Installing collected packages: cython
# Successfully installed cython-3.0.0
